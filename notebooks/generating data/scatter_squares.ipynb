# %%
# Importing Modules
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# Graph Rev 1
plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.scatter(2, 4)
plt.show()
fig.savefig('../outputs/scatter_squares/scatter_output1.png')

# %%
# Graph Rev 2
plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.scatter(2, 4, s = 200)

# Setting titles and axes names
ax.set_title('Square Numbers', fontsize = 20)
ax.set_xlabel('Value', fontsize = 14)
ax.set_ylabel('Square of Values', fontsize = 14)

# Set size of the ticks labels
ax.tick_params(axis='both', which='major', labelsize = 14)

plt.show()
fig.savefig('../outputs/scatter_squares/scatter_output2.png')

# %%
# Graph Rev 3
x_values = [1,2,3,4,5]
y_values = [1,4,9,16,25]

plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.scatter(x_values, y_values, s = 100)

# Setting titles and axes names
ax.set_title('Square Numbers', fontsize = 20)
ax.set_xlabel('Value', fontsize = 14)
ax.set_ylabel('Square of Values', fontsize = 14)

# Set size of the ticks labels
ax.tick_params(axis='both', which='major', labelsize = 14)

plt.show()
fig.savefig('../outputs/scatter_squares/scatter_output3.png')

# %%
# Graph Rev 4
x_values = range(1, 1001)
y_values = [x**2 for x in x_values]

plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.scatter(x_values, y_values, s = 10)

# Setting titles and axes names
ax.set_title('Square Numbers', fontsize = 20)
ax.set_xlabel('Value', fontsize = 14)
ax.set_ylabel('Square of Values', fontsize = 14)

# Set size of the ticks labels
ax.tick_params(axis='both', which='major', labelsize = 14)

# Set the range for each axis
ax.axis([0, 1100, 0, 1100000])

plt.show()
fig.savefig('../outputs/scatter_squares/scatter_output4.png')

# %%
# Graph Rev 5
x_values = range(1, 1001)
y_values = [x**2 for x in x_values]

plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.scatter(x_values, y_values, c='red', s = 10)

# Setting titles and axes names
ax.set_title('Square Numbers', fontsize = 20)
ax.set_xlabel('Value', fontsize = 14)
ax.set_ylabel('Square of Values', fontsize = 14)

# Set size of the ticks labels
ax.tick_params(axis='both', which='major', labelsize = 14)

# Set the range for each axis
ax.axis([0, 1100, 0, 1100000])

plt.show()
fig.savefig('../outputs/scatter_squares/scatter_output5.png')

# %%
# Graph Rev 6
x_values = range(1, 1001)
y_values = [x**2 for x in x_values]

plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.scatter(x_values, y_values, c=(0,0.8,0), s = 10)

# Setting titles and axes names
ax.set_title('Square Numbers', fontsize = 20)
ax.set_xlabel('Value', fontsize = 14)
ax.set_ylabel('Square of Values', fontsize = 14)

# Set size of the ticks labels
ax.tick_params(axis='both', which='major', labelsize = 14)

# Set the range for each axis
ax.axis([0, 1100, 0, 1100000])

plt.show()
fig.savefig('../outputs/scatter_squares/scatter_output6.png')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
# Graph Rev 7
x_values = range(1, 1001)
y_values = [x**2 for x in x_values]

plt.style.use('seaborn')
fig, ax = plt.subplots()

# Using Colormap
# Colormap references: 
ax.scatter(x_values, y_values, c = y_values, cmap = plt.cm.plasma, s = 10)

# Setting titles and axes names
ax.set_title('Square Numbers', fontsize = 20)
ax.set_xlabel('Value', fontsize = 14)
ax.set_ylabel('Square of Values', fontsize = 14)

# Set size of the ticks labels
ax.tick_params(axis='both', which='major', labelsize = 14)

# Set the range for each axis
ax.axis([0, 1100, 0, 1100000])

plt.show()
fig.savefig('../outputs/scatter_squares/scatter_output7.png', bbox_inches = 'tight')
